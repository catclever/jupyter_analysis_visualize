# %%
# ===== System-managed metadata (auto-generated, understand to edit) =====
# @node_type: compute
# @node_id: create_dict
# @execution_status: validated
# ===== End of system-managed metadata =====import pandas as pd
import numpy as np

# Create sample data
np.random.seed(42)

# DataFrame 1: Sales Data
sales_data = {
    'date': pd.date_range('2025-01-01', periods=5),
    'product': ['A', 'B', 'C', 'A', 'B'],
    'amount': [100.5, 250.3, 175.8, 320.1, 145.6]
}
df_sales = pd.DataFrame(sales_data)

# DataFrame 2: Customer Data
customer_data = {
    'customer_id': [1, 2, 3, 4, 5],
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'age': [28, 35, 42, 31, 26]
}
df_customers = pd.DataFrame(customer_data)

# DataFrame 3: Product Info
product_data = {
    'product_id': ['A', 'B', 'C', 'D'],
    'category': ['Electronics', 'Home', 'Electronics', 'Sports'],
    'price': [999.99, 49.99, 299.99, 79.99]
}
df_products = pd.DataFrame(product_data)

# Create result dictionary
create_dict = {
    'sales': df_sales,
    'customers': df_customers,
    'products': df_products
}

print("Dictionary created with keys:", list(create_dict.keys()))
for key, df in create_dict.items():
    print(f"  {key}: {df.shape[0]} rows, {df.shape[1]} columns")

# %%
# @node_id: create_dict
# @result_format: parquet
import pandas as pd
import os

# Load result from parquet
result_path = r'../projects/test_dict_simple/parquets/create_dict.parquet'
if os.path.exists(result_path):
    create_dict = pd.read_parquet(result_path)
    display(create_dict)
else:
    print(f"Result file not found: {result_path}")

# %% [markdown]
# ## ✓ Execution Complete: Create DataFrame Dictionary
#
# **Completed at:** 2025-11-18T18:14:13.181442
#
# **Execution time:** 0.02s
#
# **Status:** ✅ Success
#
# ### Execution Output
#
# ```
# Dictionary created with keys: ['sales', 'customers', 'products']
#   sales: 5 rows, 3 columns
#   customers: 5 rows, 3 columns
#   products: 4 rows, 3 columns
# Detected dict result with keys: dict_keys(['sales', 'customers', 'products'])
# Processing dict of DataFrames...
#   ✓ Saved sales: /Users/kael/Documents/泛钛客资料/space/jupyter_analysis_visualize/projects/test_dict_simple/parquets/create_dict/sales.parquet
#   ✓ Saved customers: /Users/kael/Documents/泛钛客资料/space/jupyter_analysis_visualize/projects/test_dict_simple/parquets/create_dict/customers.parquet
#   ✓ Saved products: /Users/kael/Documents/泛钛客资料/space/jupyter_analysis_visualize/projects/test_dict_simple/parquets/create_dict/products.parquet
#
# ```
#
# ---
#
# _Note: This documentation is auto-generated. For detailed AI-powered summaries, please enable summary generation in node settings._
